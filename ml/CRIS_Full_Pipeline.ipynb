# %% [markdown]
# <a href="https://colab.research.google.com/github/rishita-bisht/Cris-Ai/blob/main/CRIS_Full_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check versions (TensorFlow is pre-installed)
import pandas as pd
import numpy as np
import sklearn
import tensorflow as tf
import cv2

from google.colab import drive
drive.mount('/content/drive')

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("TensorFlow:", tf.__version__)
print("OpenCV:", cv2.__version__)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Pandas: 2.2.2
# NumPy: 2.0.2
# Scikit-learn: 1.6.1
# TensorFlow: 2.19.0
# OpenCV: 4.13.0

# %%
def generate_soldier_data(num_soldiers=50, num_days=10, seed=42):
    np.random.seed(seed)

    data = []

    for soldier in range(1, num_soldiers + 1):

        # Personal baseline
        base_hr = np.random.uniform(65, 75)
        base_hrv = np.random.uniform(50, 70)
        base_sleep = np.random.uniform(6, 8)
        base_stress = np.random.uniform(2, 4)

        for day in range(1, num_days + 1):

            activity = np.random.randint(3, 8)

            heart_rate = base_hr + np.random.normal(0, 3)
            hrv = base_hrv + np.random.normal(0, 4)
            sleep = base_sleep + np.random.normal(0, 0.5)
            stress = base_stress + np.random.normal(0, 0.7)

            # Inject anomalies
            if soldier == 2 and day >= 7:
                heart_rate += 20
                sleep -= 1.5
                stress += 3

            if soldier == 4 and day >= 6:
                heart_rate += 25
                sleep -= 2
                hrv -= 15

            data.append([
                soldier,
                day,
                round(heart_rate, 1),
                round(hrv, 1),
                round(sleep, 2),
                round(stress, 2),
                activity
            ])

    columns = [
        "soldier_id",
        "day",
        "heart_rate",
        "hrv",
        "sleep_hours",
        "stress_score",
        "activity_level"
    ]

    df = pd.DataFrame(data, columns=columns)

    return df

# %%
df = generate_soldier_data()

print("Shape:", df.shape)
print(df.head())
# Out:
# Shape: (500, 7)
#    soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 0           1    1        69.6  73.1         7.17          2.83
# 1           1    2        73.1  75.2         6.24          3.62
# 2           1    3        69.4  65.9         7.54          3.17
# 3           1    4        69.1  67.0         7.16          3.86
# 4           1    5        66.5  65.9         7.94          4.30
#
#    activity_level
# 0               4
# 1               7
# 2               6
# 3               3
# 4               7

# %%
print("Soldier 2 (Day 7-10)")
print(df[(df.soldier_id == 2) & (df.day >= 7)])

print("\nSoldier 4 (Day 6-10)")
print(df[(df.soldier_id == 4) & (df.day >= 6)])
# Out:
# Soldier 2 (Day 7-10)
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 16           2    7        86.6  70.9         6.04          6.68
# 17           2    8        87.9  65.5         5.53          6.21
# 18           2    9        82.9  65.0         5.72          5.43
# 19           2   10        81.0  62.2         5.98          5.58
#
#     activity_level
# 16               5
# 17               6
# 18               3
# 19               6
#
# Soldier 4 (Day 6-10)
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 35           4    6        98.0  39.7         3.22          3.20
# 36           4    7        94.5  50.7         4.50          3.19
# 37           4    8        99.7  41.4         3.29          3.62
# 38           4    9        97.1  32.1         4.35          3.83
# 39           4   10        92.8  33.8         3.96          4.39
#
#     activity_level
# 35               7
# 36               3
# 37               5
# 38               5
# 39               6

# %%
for soldier in df["soldier_id"].unique():
    print(f"\n--- Soldier {soldier} ---")
    print(df[df["soldier_id"] == soldier])
# Out:
# --- Soldier 1 ---
#    soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 0           1    1        69.6  73.1         7.17          2.83
# 1           1    2        73.1  75.2         6.24          3.62
# 2           1    3        69.4  65.9         7.54          3.17
# 3           1    4        69.1  67.0         7.16          3.86
# 4           1    5        66.5  65.9         7.94          4.30
# 5           1    6        68.1  70.6         6.83          3.96
# 6           1    7        67.4  69.3         7.38          4.04
# 7           1    8        69.4  72.5         6.96          2.09
# 8           1    9        75.8  73.3         7.51          3.49
# 9           1   10        69.7  67.5         7.13          3.63
#
#    activity_level
# 0               4
# 1               7
# 2               6
# 3               3
# 4               7
# 5               5
# 6               4
# 7               4
# 8               4
# 9               7
#
# --- Soldier 2 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 10           2    1        67.2  67.0         7.74          3.63
# 11           2    2        60.5  70.7         7.32          3.17
# 12           2    3        67.5  71.7         7.38          4.16
# 13           2    4        62.3  69.4         7.11          3.69
# 14           2    5        60.8  70.5         7.87          3.47
# 15           2    6        60.8  67.1         7.48          3.88
# 16           2    7        86.6  70.9         6.04          6.68
# 17           2    8        87.9  65.5         5.53          6.21
# 18           2    9        82.9  65.0         5.72          5.43
# 19           2   10        81.0  62.2         5.98          5.58
#
#     activity_level
# 10               3
# 11               3
# 12               7
# 13               7
# 14               6
# 15               7
# 16               5
# 17               6
# 18               3
# 19               6
#
# --- Soldier 3 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 20           3    1        70.5  55.8         6.07          3.47
# 21           3    2        67.3  60.6         7.08          3.19
# 22           3    3        70.0  73.7         6.44          2.70
# 23           3    4        62.4  69.8         7.62          3.35
# 24           3    5        65.9  61.2         6.47          3.47
# 25           3    6        71.6  72.6         6.04          2.09
# 26           3    7        68.6  67.3         6.90          1.82
# 27           3    8        67.7  62.8         6.47          2.92
# 28           3    9        71.3  67.6         6.12          2.96
# 29           3   10        72.3  58.9         6.65          3.40
#
#     activity_level
# 20               5
# 21               3
# 22               7
# 23               4
# 24               5
# 25               4
# 26               7
# 27               5
# 28               4
# 29               4
#
# --- Soldier 4 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 30           4    1        69.9  55.6         6.67          3.05
# 31           4    2        69.4  59.1         6.61          5.05
# 32           4    3        70.8  50.0         6.71          4.72
# 33           4    4        66.3  54.7         6.86          3.28
# 34           4    5        72.8  62.4         6.06          3.27
# 35           4    6        98.0  39.7         3.22          3.20
# 36           4    7        94.5  50.7         4.50          3.19
# 37           4    8        99.7  41.4         3.29          3.62
# 38           4    9        97.1  32.1         4.35          3.83
# 39           4   10        92.8  33.8         3.96          4.39
#
#     activity_level
# 30               7
# 31               5
# 32               3
# 33               3
# 34               5
# 35               7
# 36               3
# 37               5
# 38               5
# 39               6
#
# --- Soldier 5 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 40           5    1        66.9  56.6         8.05          3.78
# 41           5    2        68.0  58.2         6.97          3.72
# 42           5    3        67.6  62.2         7.88          4.00
# 43           5    4        63.1  63.1         7.79          2.91
# 44           5    5        62.0  69.1         7.27          4.23
# 45           5    6        61.3  62.6         7.67          3.45
# 46           5    7        60.7  62.8         7.60          3.94
# 47           5    8        64.5  62.0         7.90          2.94
# 48           5    9        70.8  64.5         7.88          3.70
# 49           5   10        64.7  64.5         7.48          3.31
#
#     activity_level
# 40               4
# 41               3
# 42               4
# 43               3
# 44               6
# 45               4
# 46               6
# 47               6
# 48               5
# 49               5
#
# --- Soldier 6 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 50           6    1        60.6  67.9         7.76          3.80
# 51           6    2        66.4  75.9         7.01          4.68
# 52           6    3        61.7  70.2         7.50          2.82
# 53           6    4        66.6  72.4         7.21          3.35
# 54           6    5        61.4  68.8         6.67          2.48
# 55           6    6        65.3  72.3         8.64          3.68
# 56           6    7        65.5  67.7         7.73          3.86
# 57           6    8        62.2  70.1         7.91          3.72
# 58           6    9        66.6  68.8         7.43          3.54
# 59           6   10        63.5  72.7         7.85          2.91
#
#     activity_level
# 50               7
# 51               7
# 52               6
# 53               6
# 54               7
# 55               4
# 56               4
# 57               4
# 58               6
# 59               7
#
# --- Soldier 7 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 60           7    1        64.6  73.1         8.41          4.79
# 61           7    2        65.9  62.7         7.14          4.42
# 62           7    3        73.6  63.1         7.04          4.16
# 63           7    4        70.3  80.6         6.70          3.02
# 64           7    5        72.3  67.0         7.52          4.02
# 65           7    6        71.9  64.3         6.75          3.80
# 66           7    7        73.2  70.1         7.46          2.98
# 67           7    8        74.2  67.0         7.06          3.38
# 68           7    9        74.0  69.5         7.50          3.65
# 69           7   10        69.8  62.1         6.68          3.66
#
#     activity_level
# 60               3
# 61               5
# 62               7
# 63               3
# 64               5
# 65               7
# 66               7
# 67               4
# 68               6
# 69               7
#
# --- Soldier 8 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 70           8    1        65.6  71.5         7.68          3.78
# 71           8    2        64.7  73.5         7.61          2.47
# 72           8    3        75.6  69.1         8.08          2.85
# 73           8    4        67.5  70.3         7.49          0.75
# 74           8    5        69.8  69.1         7.80          3.16
# 75           8    6        70.3  68.4         7.52          2.63
# 76           8    7        68.7  63.4         8.48          1.98
# 77           8    8        70.5  71.2         7.03          3.02
# 78           8    9        67.2  73.6         7.38          1.86
# 79           8   10        71.8  74.8         8.24          2.07
#
#     activity_level
# 70               3
# 71               6
# 72               6
# 73               3
# 74               3
# 75               5
# 76               3
# 77               5
# 78               6
# 79               7
#
# --- Soldier 9 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 80           9    1        76.9  46.3         7.89          4.37
# 81           9    2        71.6  52.1         7.97          2.88
# 82           9    3        71.5  58.2         7.02          3.23
# 83           9    4        71.9  53.4         7.60          4.08
# 84           9    5        67.7  55.4         8.35          4.72
# 85           9    6        61.4  52.2         7.56          4.27
# 86           9    7        78.0  60.3         7.70          4.33
# 87           9    8        76.3  56.8         7.61          3.41
# 88           9    9        72.0  54.2         8.23          5.08
# 89           9   10        71.0  56.1         8.57          3.70
#
#     activity_level
# 80               4
# 81               7
# 82               3
# 83               6
# 84               3
# 85               6
# 86               3
# 87               7
# 88               6
# 89               5
#
# --- Soldier 10 ---
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 90          10    1        72.6  61.9         7.79          3.56
# 91          10    2        72.3  56.7         7.66          3.85
# 92          10    3        76.0  58.0         8.53          3.33
# 93          10    4        67.4  58.2         7.69          4.57
# 94          10    5        69.2  63.9         8.03          3.53
# 95          10    6        66.5  60.2         7.01          3.76
# 96          10    7        67.8  59.2         7.41          3.71
# 97          10    8        69.3  70.3         7.54          3.16
# 98          10    9        71.5  60.0         7.36          4.30
# 99          10   10        69.5  68.8         7.60          3.99
#
#     activity_level
# 90               6
# 91               4
# 92               3
# 93               6
# 94               7
# 95               4
# 96               4
# 97               3
# 98               3
# 99               4
#
# --- Soldier 11 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 100          11    1        63.6  53.0         8.14          1.97
# 101          11    2        64.2  55.0         7.97          3.85
# 102          11    3        61.8  53.5         7.20          2.21
# 103          11    4        66.5  58.6         7.41          3.09
# 104          11    5        72.7  58.2         6.37          4.44
# 105          11    6        70.7  47.4         6.42          4.35
# 106          11    7        68.0  51.9         7.27          2.09
# 107          11    8        67.0  56.3         7.37          4.00
# 108          11    9        68.2  56.0         6.50          5.52
# 109          11   10        64.5  54.9         6.99          2.43
#
#      activity_level
# 100               5
# 101               3
# 102               4
# 103               4
# 104               4
# 105               7
# 106               7
# 107               5
# 108               5
# 109               7
#
# --- Soldier 12 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 110          12    1        72.4  54.9         6.67          2.04
# 111          12    2        76.3  47.1         5.53          3.38
# 112          12    3        77.2  52.4         6.12          3.33
# 113          12    4        71.2  52.4         6.27          3.11
# 114          12    5        69.7  55.3         5.93          3.63
# 115          12    6        71.3  53.2         6.37          4.67
# 116          12    7        72.5  48.0         5.98          4.56
# 117          12    8        72.2  63.7         7.23          2.12
# 118          12    9        69.4  58.1         6.68          3.29
# 119          12   10        63.2  60.6         6.84          2.60
#
#      activity_level
# 110               7
# 111               4
# 112               4
# 113               7
# 114               6
# 115               5
# 116               6
# 117               5
# 118               3
# 119               5
#
# --- Soldier 13 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 120          13    1        70.5  54.9         7.21          2.42
# 121          13    2        72.2  51.4         8.00          3.22
# 122          13    3        72.2  49.5         7.37          1.45
# 123          13    4        75.8  51.6         7.54          2.60
# 124          13    5        75.9  61.3         8.12          4.09
# 125          13    6        66.6  59.3         8.08          2.95
# 126          13    7        71.1  51.6         8.08          4.09
# 127          13    8        77.3  55.7         7.87          3.30
# 128          13    9        70.1  58.5         7.44          2.64
# 129          13   10        72.1  57.7         6.91          4.06
#
#      activity_level
# 120               5
# 121               3
# 122               3
# 123               6
# 124               6
# 125               6
# 126               6
# 127               6
# 128               4
# 129               6
#
# --- Soldier 14 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 130          14    1        64.9  52.9         6.83          0.06
# 131          14    2        61.0  55.7         7.04          1.90
# 132          14    3        57.5  56.5         7.49          2.50
# 133          14    4        62.5  58.8         7.21          1.89
# 134          14    5        63.8  53.1         7.17          0.88
# 135          14    6        66.1  56.1         7.32          1.63
# 136          14    7        68.8  55.1         6.78          2.50
# 137          14    8        69.7  46.1         6.57          1.14
# 138          14    9        64.5  55.2         6.90          1.46
# 139          14   10        64.5  56.4         7.85          1.47
#
#      activity_level
# 130               3
# 131               5
# 132               3
# 133               5
# 134               7
# 135               5
# 136               7
# 137               5
# 138               5
# 139               4
#
# --- Soldier 15 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 140          15    1        79.3  51.1         6.85          1.15
# 141          15    2        67.9  53.4         6.32          2.20
# 142          15    3        70.8  46.3         6.14          2.28
# 143          15    4        66.6  57.6         5.82          1.89
# 144          15    5        70.6  50.2         6.21          3.17
# 145          15    6        66.3  48.4         6.93          2.44
# 146          15    7        78.4  39.4         6.88          3.20
# 147          15    8        69.7  48.9         5.80          2.53
# 148          15    9        72.2  46.6         6.65          1.27
# 149          15   10        77.0  50.5         5.99          1.83
#
#      activity_level
# 140               5
# 141               5
# 142               5
# 143               4
# 144               4
# 145               3
# 146               3
# 147               3
# 148               7
# 149               3
#
# --- Soldier 16 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 150          16    1        71.8  58.2         7.46          1.33
# 151          16    2        73.9  52.1         7.36          2.46
# 152          16    3        74.8  54.5         7.64          4.04
# 153          16    4        73.9  54.5         7.24          2.21
# 154          16    5        70.6  55.5         8.55          2.92
# 155          16    6        70.9  64.2         6.63          2.06
# 156          16    7        78.2  54.8         6.49          2.71
# 157          16    8        71.4  52.4         7.60          3.70
# 158          16    9        72.9  49.7         7.46          3.42
# 159          16   10        74.7  58.7         7.29          3.00
#
#      activity_level
# 150               4
# 151               4
# 152               4
# 153               4
# 154               4
# 155               4
# 156               3
# 157               5
# 158               3
# 159               7
#
# --- Soldier 17 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 160          17    1        76.5  63.5         7.61          1.95
# 161          17    2        78.1  61.5         8.06          0.20
# 162          17    3        70.2  68.6         6.96          4.02
# 163          17    4        70.9  68.0         7.26          2.20
# 164          17    5        80.2  64.9         7.46          3.30
# 165          17    6        70.0  65.3         7.74          2.14
# 166          17    7        74.0  60.7         6.58          2.50
# 167          17    8        72.7  68.7         8.18          1.74
# 168          17    9        73.1  59.7         6.88          1.37
# 169          17   10        73.9  63.9         8.16          1.40
#
#      activity_level
# 160               4
# 161               4
# 162               3
# 163               5
# 164               3
# 165               7
# 166               5
# 167               3
# 168               3
# 169               7
#
# --- Soldier 18 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 170          18    1        66.9  69.2         8.14          1.95
# 171          18    2        66.8  67.0         7.81          2.53
# 172          18    3        74.7  70.9         6.72          2.30
# 173          18    4        69.6  73.2         7.74          1.92
# 174          18    5        67.8  62.9         8.35          3.44
# 175          18    6        60.4  65.5         7.48          0.95
# 176          18    7        68.8  73.3         7.15          2.25
# 177          18    8        63.0  66.1         7.56          3.44
# 178          18    9        69.3  64.8         5.83          1.57
# 179          18   10        67.6  72.5         7.85          3.59
#
#      activity_level
# 170               5
# 171               7
# 172               3
# 173               5
# 174               7
# 175               4
# 176               5
# 177               6
# 178               7
# 179               7
#
# --- Soldier 19 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 180          19    1        76.1  66.7         7.58          4.55
# 181          19    2        71.7  66.6         6.86          3.15
# 182          19    3        74.9  66.3         6.93          3.74
# 183          19    4        74.2  64.9         6.36          4.26
# 184          19    5        72.5  62.0         7.02          3.51
# 185          19    6        77.3  58.9         7.13          4.02
# 186          19    7        75.9  68.6         6.69          3.71
# 187          19    8        71.9  72.3         7.59          4.94
# 188          19    9        73.3  56.5         7.41          4.49
# 189          19   10        73.3  59.8         7.09          4.55
#
#      activity_level
# 180               6
# 181               5
# 182               4
# 183               7
# 184               6
# 185               4
# 186               4
# 187               5
# 188               6
# 189               4
#
# --- Soldier 20 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 190          20    1        69.4  59.5         8.00          3.48
# 191          20    2        69.6  62.6         8.13          3.40
# 192          20    3        69.5  61.7         7.64          4.33
# 193          20    4        74.1  55.0         8.03          4.05
# 194          20    5        75.2  61.3         7.78          4.04
# 195          20    6        69.0  58.4         6.94          3.77
# 196          20    7        73.6  53.2         8.10          3.09
# 197          20    8        79.1  54.4         7.84          3.50
# 198          20    9        75.6  57.7         7.20          3.51
# 199          20   10        73.7  52.3         7.67          3.28
#
#      activity_level
# 190               6
# 191               7
# 192               4
# 193               6
# 194               4
# 195               3
# 196               6
# 197               5
# 198               5
# 199               3
#
# --- Soldier 21 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 200          21    1        64.5  57.1         7.42          3.82
# 201          21    2        62.9  52.5         8.01          4.27
# 202          21    3        71.3  60.6         7.58          3.43
# 203          21    4        70.9  59.2         7.38          5.57
# 204          21    5        67.4  60.7         7.45          4.80
# 205          21    6        72.2  55.1         8.42          4.64
# 206          21    7        66.1  58.6         7.81          3.48
# 207          21    8        63.2  61.7         7.31          6.05
# 208          21    9        68.9  52.8         7.42          2.71
# 209          21   10        69.9  60.4         6.62          3.25
#
#      activity_level
# 200               3
# 201               6
# 202               4
# 203               4
# 204               5
# 205               5
# 206               3
# 207               5
# 208               6
# 209               7
#
# --- Soldier 22 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 210          22    1        73.8  67.9         6.62          3.71
# 211          22    2        70.5  74.3         5.44          2.65
# 212          22    3        72.8  72.9         6.28          3.25
# 213          22    4        69.7  68.6         5.25          3.70
# 214          22    5        73.5  63.2         6.99          4.35
# 215          22    6        69.8  69.4         6.48          2.86
# 216          22    7        67.3  71.1         6.06          4.07
# 217          22    8        68.3  73.7         5.78          2.37
# 218          22    9        67.9  74.7         6.40          2.76
# 219          22   10        66.5  64.5         6.78          2.61
#
#      activity_level
# 210               3
# 211               4
# 212               4
# 213               4
# 214               6
# 215               3
# 216               3
# 217               5
# 218               6
# 219               3
#
# --- Soldier 23 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 220          23    1        69.1  65.0         7.31          3.44
# 221          23    2        67.6  58.9         7.64          3.08
# 222          23    3        70.8  60.3         7.60          2.01
# 223          23    4        69.0  62.5         7.50          4.17
# 224          23    5        74.8  60.1         8.12          2.68
# 225          23    6        66.4  62.7         7.86          2.84
# 226          23    7        71.8  60.0         7.84          2.77
# 227          23    8        68.3  60.6         7.90          3.05
# 228          23    9        71.9  65.4         7.88          2.61
# 229          23   10        71.1  67.9         7.07          3.10
#
#      activity_level
# 220               6
# 221               4
# 222               5
# 223               6
# 224               5
# 225               4
# 226               7
# 227               4
# 228               3
# 229               7
#
# --- Soldier 24 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 230          24    1        72.1  62.1         8.02          4.24
# 231          24    2        73.8  55.8         7.55          4.51
# 232          24    3        70.6  56.9         7.65          4.00
# 233          24    4        67.2  49.8         7.29          5.07
# 234          24    5        74.2  65.3         7.58          3.96
# 235          24    6        76.0  60.4         7.39          5.56
# 236          24    7        72.9  56.6         7.78          3.16
# 237          24    8        63.8  54.2         8.55          4.21
# 238          24    9        73.3  57.5         7.78          3.94
# 239          24   10        70.5  58.6         7.72          3.32
#
#      activity_level
# 230               7
# 231               7
# 232               7
# 233               3
# 234               3
# 235               5
# 236               5
# 237               6
# 238               6
# 239               6
#
# --- Soldier 25 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 240          25    1        65.1  56.4         6.26          4.70
# 241          25    2        64.6  54.8         6.89          2.93
# 242          25    3        65.9  57.8         7.09          3.14
# 243          25    4        71.8  55.4         6.33          3.65
# 244          25    5        68.3  64.7         7.28          3.90
# 245          25    6        66.2  51.4         6.70          3.79
# 246          25    7        69.8  52.9         7.02          3.21
# 247          25    8        70.7  58.0         6.33          3.91
# 248          25    9        66.2  53.4         6.57          4.37
# 249          25   10        71.2  62.2         5.85          3.79
#
#      activity_level
# 240               5
# 241               7
# 242               4
# 243               7
# 244               4
# 245               4
# 246               3
# 247               6
# 248               4
# 249               7
#
# --- Soldier 26 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 250          26    1        73.9  65.6         6.06          2.59
# 251          26    2        70.6  68.4         6.80          3.83
# 252          26    3        65.6  59.0         6.70          3.84
# 253          26    4        70.4  65.8         7.09          3.55
# 254          26    5        65.6  64.8         6.31          3.84
# 255          26    6        73.9  63.6         6.64          3.94
# 256          26    7        72.8  64.7         6.83          3.14
# 257          26    8        61.9  59.9         6.62          4.53
# 258          26    9        68.2  60.3         7.21          4.21
# 259          26   10        70.4  64.2         6.46          3.35
#
#      activity_level
# 250               5
# 251               3
# 252               7
# 253               3
# 254               4
# 255               4
# 256               6
# 257               3
# 258               7
# 259               7
#
# --- Soldier 27 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 260          27    1        66.9  55.0         8.10          2.74
# 261          27    2        67.4  53.6         7.65          3.92
# 262          27    3        69.4  53.0         7.54          3.80
# 263          27    4        67.3  49.6         7.92          3.49
# 264          27    5        67.9  52.5         9.11          2.90
# 265          27    6        69.5  51.3         8.13          3.81
# 266          27    7        70.1  52.0         6.97          2.66
# 267          27    8        65.8  51.2         7.27          3.53
# 268          27    9        65.7  53.4         7.53          3.06
# 269          27   10        70.5  57.3         7.57          1.89
#
#      activity_level
# 260               5
# 261               6
# 262               4
# 263               3
# 264               4
# 265               7
# 266               4
# 267               6
# 268               4
# 269               5
#
# --- Soldier 28 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 270          28    1        71.3  56.9         7.20          2.01
# 271          28    2        69.6  45.6         6.29          3.18
# 272          28    3        66.3  55.5         7.31          1.71
# 273          28    4        62.8  51.2         7.77          2.46
# 274          28    5        66.0  47.3         7.76          3.49
# 275          28    6        68.1  46.7         8.03          2.19
# 276          28    7        66.7  53.8         7.63          1.85
# 277          28    8        63.1  51.3         8.15          1.93
# 278          28    9        62.6  45.0         8.30          2.38
# 279          28   10        68.1  52.2         7.73          2.41
#
#      activity_level
# 270               6
# 271               6
# 272               7
# 273               6
# 274               4
# 275               4
# 276               7
# 277               7
# 278               5
# 279               7
#
# --- Soldier 29 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 280          29    1        63.0  64.5         7.59          3.67
# 281          29    2        68.9  62.9         8.66          3.09
# 282          29    3        70.8  67.9         6.43          3.12
# 283          29    4        71.1  63.0         7.13          3.37
# 284          29    5        71.3  56.8         7.25          2.89
# 285          29    6        68.1  66.6         7.22          2.37
# 286          29    7        68.9  74.3         7.33          3.64
# 287          29    8        71.9  72.8         8.02          3.41
# 288          29    9        68.2  62.0         7.53          2.45
# 289          29   10        64.2  64.1         7.81          2.87
#
#      activity_level
# 280               5
# 281               7
# 282               7
# 283               6
# 284               5
# 285               6
# 286               3
# 287               4
# 288               6
# 289               6
#
# --- Soldier 30 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 290          30    1        72.7  61.0         6.44          3.42
# 291          30    2        67.9  60.9         5.95          3.73
# 292          30    3        72.6  53.1         5.76          4.20
# 293          30    4        74.2  62.2         6.04          2.94
# 294          30    5        72.7  66.7         6.15          5.81
# 295          30    6        74.8  60.7         5.43          3.82
# 296          30    7        71.1  56.5         5.74          4.40
# 297          30    8        74.0  62.3         6.80          4.65
# 298          30    9        76.7  70.4         6.14          4.15
# 299          30   10        69.4  62.5         5.96          4.28
#
#      activity_level
# 290               4
# 291               7
# 292               5
# 293               7
# 294               6
# 295               5
# 296               4
# 297               4
# 298               7
# 299               6
#
# --- Soldier 31 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 300          31    1        67.4  49.2         7.22          4.19
# 301          31    2        69.5  49.5         6.40          2.93
# 302          31    3        66.6  63.2         6.33          3.88
# 303          31    4        73.9  60.5         7.43          4.42
# 304          31    5        67.4  53.2         7.16          2.76
# 305          31    6        67.8  51.2         6.96          4.42
# 306          31    7        59.9  56.2         6.40          3.13
# 307          31    8        68.0  52.5         7.37          4.19
# 308          31    9        65.5  57.2         6.84          3.00
# 309          31   10        67.2  54.0         7.18          3.54
#
#      activity_level
# 300               7
# 301               5
# 302               3
# 303               4
# 304               4
# 305               5
# 306               6
# 307               3
# 308               5
# 309               6
#
# --- Soldier 32 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 310          32    1        71.0  68.1         8.02          2.88
# 311          32    2        69.8  60.8         6.94          1.25
# 312          32    3        66.8  52.5         5.82          1.81
# 313          32    4        71.6  67.1         7.23          2.47
# 314          32    5        67.0  63.3         6.68          2.58
# 315          32    6        69.9  61.9         6.69          1.74
# 316          32    7        71.5  58.7         7.14          2.54
# 317          32    8        67.4  64.3         7.26          2.25
# 318          32    9        69.1  56.9         6.29          1.65
# 319          32   10        69.9  68.2         7.76          2.11
#
#      activity_level
# 310               7
# 311               5
# 312               5
# 313               7
# 314               6
# 315               6
# 316               5
# 317               4
# 318               5
# 319               4
#
# --- Soldier 33 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 320          33    1        69.5  64.8         6.32          5.65
# 321          33    2        71.1  69.0         7.12          3.55
# 322          33    3        69.8  62.7         7.20          4.44
# 323          33    4        73.6  68.2         6.32          4.35
# 324          33    5        69.1  62.3         6.76          5.37
# 325          33    6        74.7  70.7         7.00          3.45
# 326          33    7        73.1  62.4         6.98          4.98
# 327          33    8        71.4  58.7         7.05          5.10
# 328          33    9        70.0  64.3         7.78          4.23
# 329          33   10        75.5  62.2         6.90          6.19
#
#      activity_level
# 320               7
# 321               3
# 322               3
# 323               3
# 324               4
# 325               5
# 326               6
# 327               7
# 328               7
# 329               3
#
# --- Soldier 34 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 330          34    1        62.0  62.1         8.28          2.27
# 331          34    2        69.6  65.3         8.03          2.63
# 332          34    3        67.5  59.8         7.32          3.48
# 333          34    4        68.4  62.0         7.66          1.86
# 334          34    5        64.4  61.1         7.79          3.29
# 335          34    6        69.1  60.6         7.81          2.38
# 336          34    7        66.8  63.0         8.22          3.76
# 337          34    8        63.5  64.6         7.34          2.95
# 338          34    9        67.8  64.4         7.74          2.51
# 339          34   10        62.3  59.1         7.78          3.27
#
#      activity_level
# 330               5
# 331               7
# 332               4
# 333               5
# 334               6
# 335               5
# 336               3
# 337               6
# 338               6
# 339               7
#
# --- Soldier 35 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 340          35    1        66.8  53.9         7.76          3.44
# 341          35    2        67.0  51.4         8.45          3.53
# 342          35    3        74.0  48.6         8.04          4.19
# 343          35    4        65.4  56.4         7.05          4.59
# 344          35    5        65.4  57.1         8.07          3.49
# 345          35    6        69.7  55.8         7.81          4.10
# 346          35    7        70.7  56.5         6.86          2.76
# 347          35    8        65.3  53.9         8.29          3.50
# 348          35    9        66.5  54.7         7.80          3.89
# 349          35   10        69.7  54.0         8.01          4.19
#
#      activity_level
# 340               4
# 341               5
# 342               3
# 343               5
# 344               6
# 345               7
# 346               5
# 347               6
# 348               5
# 349               3
#
# --- Soldier 36 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 350          36    1        67.2  67.7         7.62          2.16
# 351          36    2        64.8  68.4         7.50          2.20
# 352          36    3        67.6  62.8         6.93          1.86
# 353          36    4        66.5  72.9         7.90          2.76
# 354          36    5        63.7  72.4         6.64          2.26
# 355          36    6        70.8  72.7         7.05          2.11
# 356          36    7        66.0  71.8         7.78          4.49
# 357          36    8        65.0  72.8         7.26          1.99
# 358          36    9        71.5  64.8         8.06          3.83
# 359          36   10        69.4  73.7         7.27          2.26
#
#      activity_level
# 350               3
# 351               7
# 352               6
# 353               3
# 354               7
# 355               4
# 356               6
# 357               6
# 358               6
# 359               7
#
# --- Soldier 37 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 360          37    1        73.0  76.2         6.21          2.68
# 361          37    2        75.3  70.2         6.43          1.43
# 362          37    3        72.2  61.1         6.75          1.68
# 363          37    4        80.3  66.6         7.10          2.63
# 364          37    5        71.9  66.4         6.68          3.48
# 365          37    6        74.0  68.7         6.14          2.41
# 366          37    7        73.3  74.7         6.62          3.24
# 367          37    8        72.0  69.9         6.90          2.48
# 368          37    9        68.7  62.0         6.94          2.42
# 369          37   10        75.4  64.8         7.05          1.86
#
#      activity_level
# 360               5
# 361               3
# 362               3
# 363               7
# 364               3
# 365               4
# 366               3
# 367               7
# 368               7
# 369               7
#
# --- Soldier 38 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 370          38    1        73.4  66.7         8.26          2.42
# 371          38    2        71.9  63.2         8.49          1.66
# 372          38    3        69.5  60.8         7.46          3.06
# 373          38    4        71.3  70.1         7.68          2.02
# 374          38    5        73.6  63.2         8.39          2.54
# 375          38    6        74.7  61.4         6.88          1.55
# 376          38    7        74.0  61.4         7.64          0.96
# 377          38    8        74.0  61.8         7.58          2.76
# 378          38    9        71.7  60.0         7.59          3.01
# 379          38   10        71.8  55.8         8.47          2.32
#
#      activity_level
# 370               7
# 371               6
# 372               3
# 373               7
# 374               4
# 375               7
# 376               3
# 377               3
# 378               7
# 379               4
#
# --- Soldier 39 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 380          39    1        67.7  58.2         5.39          2.77
# 381          39    2        65.5  69.5         4.85          2.97
# 382          39    3        64.3  67.0         5.18          2.18
# 383          39    4        69.7  68.2         6.78          4.17
# 384          39    5        62.6  68.2         5.97          2.63
# 385          39    6        62.7  66.3         5.12          2.49
# 386          39    7        64.7  72.1         5.79          1.14
# 387          39    8        66.0  68.4         6.13          2.20
# 388          39    9        73.9  60.6         5.77          2.27
# 389          39   10        69.2  65.9         5.59          3.13
#
#      activity_level
# 380               6
# 381               6
# 382               5
# 383               7
# 384               6
# 385               5
# 386               7
# 387               6
# 388               6
# 389               5
#
# --- Soldier 40 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 390          40    1        73.0  56.2         6.38          2.89
# 391          40    2        62.5  62.4         7.02          5.03
# 392          40    3        75.2  62.4         6.51          3.60
# 393          40    4        65.5  64.5         6.60          4.90
# 394          40    5        68.0  63.9         6.29          5.04
# 395          40    6        71.2  63.4         7.03          3.63
# 396          40    7        79.8  58.6         5.56          5.02
# 397          40    8        63.7  76.1         7.00          3.82
# 398          40    9        73.7  62.2         6.68          4.71
# 399          40   10        70.6  63.5         5.78          4.34
#
#      activity_level
# 390               6
# 391               4
# 392               4
# 393               7
# 394               6
# 395               4
# 396               4
# 397               5
# 398               5
# 399               7
#
# --- Soldier 41 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 400          41    1        73.3  55.3         6.99          2.83
# 401          41    2        71.7  61.5         6.25          2.77
# 402          41    3        70.3  58.3         6.87          2.42
# 403          41    4        67.9  56.8         6.20          2.28
# 404          41    5        64.5  60.1         6.75          0.76
# 405          41    6        72.6  58.9         6.71          2.62
# 406          41    7        71.8  56.3         6.42          2.12
# 407          41    8        70.3  61.2         6.73          1.82
# 408          41    9        69.9  55.5         6.38          0.66
# 409          41   10        63.0  57.3         7.25          1.73
#
#      activity_level
# 400               7
# 401               4
# 402               5
# 403               3
# 404               3
# 405               6
# 406               3
# 407               4
# 408               5
# 409               3
#
# --- Soldier 42 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 410          42    1        64.9  65.2         7.18          3.46
# 411          42    2        64.6  60.3         8.00          1.69
# 412          42    3        68.1  62.4         7.72          1.67
# 413          42    4        67.9  60.6         7.42          2.92
# 414          42    5        64.3  68.9         7.60          2.36
# 415          42    6        70.1  65.2         8.16          3.01
# 416          42    7        69.4  63.8         7.93          2.84
# 417          42    8        69.1  64.8         7.96          3.54
# 418          42    9        69.8  69.3         7.78          3.05
# 419          42   10        67.5  63.3         7.51          3.01
#
#      activity_level
# 410               6
# 411               6
# 412               6
# 413               4
# 414               3
# 415               5
# 416               5
# 417               7
# 418               7
# 419               3
#
# --- Soldier 43 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 420          43    1        72.4  71.7         7.11          1.94
# 421          43    2        67.4  71.1         6.82          4.34
# 422          43    3        70.5  72.2         6.95          2.56
# 423          43    4        66.0  73.6         6.41          4.02
# 424          43    5        67.6  71.5         6.73          2.75
# 425          43    6        65.8  69.5         6.46          3.42
# 426          43    7        67.9  58.6         7.39          1.18
# 427          43    8        68.5  68.1         7.01          3.25
# 428          43    9        71.8  66.2         7.06          3.95
# 429          43   10        69.3  73.5         6.90          2.38
#
#      activity_level
# 420               4
# 421               6
# 422               3
# 423               6
# 424               3
# 425               4
# 426               4
# 427               6
# 428               3
# 429               4
#
# --- Soldier 44 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 430          44    1        69.0  59.8         6.25          1.64
# 431          44    2        70.5  61.6         7.05          3.20
# 432          44    3        69.8  58.2         6.40          2.20
# 433          44    4        67.5  52.9         6.50          2.11
# 434          44    5        66.6  53.5         7.30          3.91
# 435          44    6        69.2  47.3         7.52          3.61
# 436          44    7        66.7  56.2         7.26          3.68
# 437          44    8        72.5  55.9         6.32          2.84
# 438          44    9        71.4  53.9         7.09          1.94
# 439          44   10        70.6  52.7         6.74          1.38
#
#      activity_level
# 430               3
# 431               5
# 432               5
# 433               5
# 434               6
# 435               3
# 436               6
# 437               3
# 438               7
# 439               3
#
# --- Soldier 45 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 440          45    1        69.2  64.1         6.07          1.91
# 441          45    2        71.8  69.2         6.45          2.42
# 442          45    3        70.0  64.9         7.27          1.20
# 443          45    4        76.8  64.0         5.71          2.58
# 444          45    5        75.2  65.6         6.15          2.53
# 445          45    6        76.4  63.8         5.87          1.89
# 446          45    7        75.2  64.2         5.80          2.64
# 447          45    8        76.1  59.0         5.65          2.63
# 448          45    9        73.9  70.4         6.43          2.15
# 449          45   10        72.4  66.0         6.82          2.34
#
#      activity_level
# 440               7
# 441               5
# 442               4
# 443               7
# 444               5
# 445               5
# 446               4
# 447               6
# 448               4
# 449               4
#
# --- Soldier 46 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 450          46    1        66.5  52.3         7.18          3.66
# 451          46    2        78.0  49.1         7.93          3.57
# 452          46    3        68.3  55.5         6.86          4.20
# 453          46    4        65.5  58.1         5.82          4.41
# 454          46    5        65.1  57.9         6.26          4.29
# 455          46    6        62.9  62.8         7.08          5.63
# 456          46    7        67.0  55.6         7.25          3.68
# 457          46    8        67.0  58.6         6.74          4.85
# 458          46    9        68.8  49.6         6.53          3.07
# 459          46   10        63.4  60.5         7.14          3.53
#
#      activity_level
# 450               7
# 451               5
# 452               6
# 453               3
# 454               6
# 455               6
# 456               4
# 457               4
# 458               4
# 459               6
#
# --- Soldier 47 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 460          47    1        72.7  54.9         7.18          2.39
# 461          47    2        67.8  51.7         7.84          1.97
# 462          47    3        71.7  41.7         7.29          1.38
# 463          47    4        72.6  51.3         8.21          1.46
# 464          47    5        71.6  53.8         6.79          1.62
# 465          47    6        72.2  54.2         7.42          1.30
# 466          47    7        71.7  48.9         7.07          2.19
# 467          47    8        74.1  49.9         6.78          2.19
# 468          47    9        62.9  50.7         7.73          2.44
# 469          47   10        68.4  52.9         8.65          4.27
#
#      activity_level
# 460               6
# 461               3
# 462               7
# 463               7
# 464               6
# 465               7
# 466               5
# 467               5
# 468               4
# 469               5
#
# --- Soldier 48 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 470          48    1        67.9  69.5         7.55          3.35
# 471          48    2        67.0  64.3         7.87          3.94
# 472          48    3        66.6  76.2         6.71          3.74
# 473          48    4        70.1  66.5         7.30          4.41
# 474          48    5        67.5  69.9         7.90          4.27
# 475          48    6        64.1  67.2         8.10          3.80
# 476          48    7        75.6  76.4         6.77          2.94
# 477          48    8        69.3  69.6         8.18          4.44
# 478          48    9        69.8  71.9         7.33          3.93
# 479          48   10        64.7  71.4         7.46          3.10
#
#      activity_level
# 470               5
# 471               3
# 472               6
# 473               4
# 474               5
# 475               4
# 476               3
# 477               7
# 478               4
# 479               5
#
# --- Soldier 49 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 480          49    1        68.2  57.1         5.67          3.24
# 481          49    2        63.6  51.0         5.82          3.69
# 482          49    3        63.7  52.8         6.10          3.06
# 483          49    4        66.6  63.2         6.37          2.64
# 484          49    5        64.5  54.1         6.83          3.55
# 485          49    6        65.5  52.0         6.47          2.33
# 486          49    7        60.0  57.3         6.86          1.92
# 487          49    8        63.0  58.5         6.11          2.63
# 488          49    9        62.5  57.4         7.41          3.36
# 489          49   10        68.2  49.8         7.36          2.43
#
#      activity_level
# 480               3
# 481               3
# 482               4
# 483               5
# 484               4
# 485               3
# 486               4
# 487               4
# 488               6
# 489               5
#
# --- Soldier 50 ---
#      soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 490          50    1        72.5  61.9         6.69          1.08
# 491          50    2        69.3  59.9         5.81          3.08
# 492          50    3        72.9  60.8         6.86          1.38
# 493          50    4        68.3  63.3         6.49          3.48
# 494          50    5        68.2  60.0         6.66          2.14
# 495          50    6        71.6  61.7         5.09          2.41
# 496          50    7        76.1  66.0         5.85          2.49
# 497          50    8        72.6  56.0         6.01          0.69
# 498          50    9        75.6  67.1         5.76          1.21
# 499          50   10        72.3  62.4         6.54          2.52
#
#      activity_level
# 490               6
# 491               4
# 492               3
# 493               4
# 494               5
# 495               6
# 496               5
# 497               6
# 498               4
# 499               4

# %%
def compute_zscore_anomalies(df, threshold=2):
    df = df.copy()

    df["anomaly_flag"] = False
    df["anomaly_reason"] = ""

    for soldier in df["soldier_id"].unique():

        soldier_data = df[df["soldier_id"] == soldier]

        # Baseline = first 5 days
        baseline = soldier_data[soldier_data["day"] <= 5]

        means = baseline[["heart_rate", "hrv", "sleep_hours", "stress_score"]].mean()
        stds = baseline[["heart_rate", "hrv", "sleep_hours", "stress_score"]].std()

        # Avoid division by zero
        stds = stds.replace(0, 0.01)

        # Evaluate days 6-10
        for idx, row in soldier_data[soldier_data["day"] >= 6].iterrows():

            reasons = []

            for metric in ["heart_rate", "hrv", "sleep_hours", "stress_score"]:
                z = (row[metric] - means[metric]) / stds[metric]

                if abs(z) > threshold:
                    reasons.append(f"{metric} abnormal (Z={round(z,2)})")

            if reasons:
                df.loc[idx, "anomaly_flag"] = True
                df.loc[idx, "anomaly_reason"] = ", ".join(reasons)

    return df

# %%
df = compute_zscore_anomalies(df)

print("Total anomalies detected:", df["anomaly_flag"].sum())

df[(df["soldier_id"] == 2) & (df["day"] >= 6)]
df[(df["soldier_id"] == 4) & (df["day"] >= 6)]
# Out:
# Total anomalies detected: 114
#     soldier_id  day  heart_rate   hrv  sleep_hours  stress_score  \
# 35           4    6        98.0  39.7         3.22          3.20
# 36           4    7        94.5  50.7         4.50          3.19
# 37           4    8        99.7  41.4         3.29          3.62
# 38           4    9        97.1  32.1         4.35          3.83
# 39           4   10        92.8  33.8         3.96          4.39
#
#     activity_level  anomaly_flag  \
# 35               7          True
# 36               3          True
# 37               5          True
# 38               5          True
# 39               6          True
#
#                                        anomaly_reason
# 35  heart_rate abnormal (Z=11.9), hrv abnormal (Z=...
# 36  heart_rate abnormal (Z=10.42), sleep_hours abn...
# 37  heart_rate abnormal (Z=12.61), hrv abnormal (Z...
# 38  heart_rate abnormal (Z=11.52), hrv abnormal (Z...
# 39  heart_rate abnormal (Z=9.7), hrv abnormal (Z=-...
